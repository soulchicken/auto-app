# %% [markdown]
# # 퓨젼

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import random
import time
import copy
import pyperclip
import pyautogui

# %%
# 크롬에서 토스를 연다

driver = webdriver.Chrome() # Driver가 있는 path를 넣어 줄 수 있음

time.sleep(2)

driver.get("https://app.tosspayments.com/")

# %%
elems = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div/section/div[3]/div[3]/table/tbody')
#print(elems)
# print(elems.text)
#print(elems.find_elements(By.TAG_NAME,'td'))

#for i in elems.find_elements(By.TAG_NAME,'td'):
#     print(i.text, '-----------')

# print(elems.find_elements_by_class_name('text--left'))

n = 0
li = []
l = []

for i in elems.find_elements(By.CLASS_NAME,'text--left'):
    if n % 10 == 0:
#         print("날짜 : ",i.text)
        l.append(i.text)
    elif n % 10 == 2: # 결제 완료 여부
        l.append(i.text)
    elif n % 10 == 3:
#         print("컨텐츠 : ",i.text)
        l.append(i.text)
    elif n % 10 == 5:
#         print("이름 : ",i.text)
        l.append(i.text)
    elif n % 10 == 7:
#         print("번호 : ",i.text)
        l.append(i.text)
        li.append(l)
        l = []
    n += 1
        # elems2 = elems.find_element_by_class_name('table__cell text--left')
#for elem in elems:
#    print(elem.text)

# %%
li
# Out:
# [['2022-07-04  14:07:25',
#   '결제완료',
#   '🌙한월하 : 차가운 달빛 아래 (5인용) / 50% 할인 특가🔥',
#   '지다희',
#   '010-2829-9085'],
#  ['2022-07-04  14:06:36',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 (2인용) / 50% 할인 특가🔥',
#   '박슬기',
#   '010-2215-0532'],
#  ['2022-07-04  13:52:11',
#   '결제완료',
#   '🌙한월하 : 차가운 달빛 아래 (5인용) / 50% 할인 특가🔥',
#   '홍범석',
#   '010-9699-8712'],
#  ['2022-07-04  13:47:26',
#   '결제완료',
#   '🌙한월하 : 차가운 달빛 아래 (5인용) / 50% 할인 특가🔥',
#   '박태현',
#   '010-9416-2486'],
#  ['2022-07-04  13:46:34',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 (5인용) / 50% 할인 특가🔥',
#   '박태현',
#   '010-9416-2486'],
#  ['2022-07-04  13:00:19',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 (1인용) / 50% 할인 특가🔥',
#   '서정윤',
#   '010-6578-1032'],
#  ['2022-07-04  12:48:00',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 (1인용) / 50% 할인 특가🔥',
#   '문기원',
#   '010-2905-0969'],
#  ['2022-07-04  11:43:07',
#   '결제완료',
#   '🌙한월하 : 차가운 달빛 아래 (5인용) / 50% 할인 특가🔥',
#   '이아영',
#   '010-8601-0848'],
#  ['2022-07-03  20:44:27',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 / 2인용 (30% 할인코드 적용)',
#   '김영진',
#   '010-7354-0059'],
#  ['2022-07-03  18:34:35',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 (1인용) / 50% 할인 특가🔥',
#   '차한성',
#   '010-4053-0623'],
#  ['2022-07-03  15:26:29',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 / 2인용 (30% 할인코드 적용)',
#   '박나영',
#   '010-5789-5984'],
#  ['2022-07-02  21:47:27',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 / 3인용 (30% 할인코드 적용)',
#   '여성진',
#   '010-9295-8095'],
#  ['2022-07-02  20:05:18',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 / 4인용 (30% 할인코드 적용)',
#   '조한솔',
#   '010-8225-1107'],
#  ['2022-07-02  18:34:32',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 / 2인용 (30% 할인코드 적용)',
#   '홍정우',
#   '010-3865-7520'],
#  ['2022-07-01  22:45:35',
#   '결제완료',
#   '✉️이야기를 전해드릴게요 (1인용) / 50% 할인 특가🔥',
#   '김나연',
#   '010-3159-5220']]

# %%
# 메뉴파인딩 함수
# Todo : 파일 입출력으로 변경

def find_menu(str):
    ans = 'https://www.google.com/'
    lines = []
    if '레다 크라임씬 EP.01' in str:
        with open('crime.txt', 'r') as file:    # hello.txt 파일을 읽기 모드(r)로 열기
            lines = file.readlines()
            ans = lines.pop(0)
        
        with open('crime.txt', 'w') as file:    # hello.txt 파일을 읽기 모드(r)로 열기
            file.writelines(lines)
            
    elif "한월하 : 차가운 달빛 아래" in str:
        with open('underlunar.txt', 'r') as file:    # hello.txt 파일을 읽기 모드(r)로 열기
            lines = file.readlines()
            ans = lines.pop(0)
        
        with open('underlunar.txt', 'w') as file:    # hello.txt 파일을 읽기 모드(r)로 열기
            file.writelines(lines)
    
    elif '이야기를 전해드릴게요' in str:
        with open('story.txt', 'r') as file:    # hello.txt 파일을 읽기 모드(r)로 열기
            lines = file.readlines()
            ans = lines.pop(0)

        with open('story.txt', 'w') as file:    # hello.txt 파일을 읽기 모드(r)로 열기
            file.writelines(lines)
    return ans

# %%
print(find_menu('✉️이야기를 전해드릴게요 / 3인용 (30% 할인코드 적용)'))
# Out:
# 1daum.net

# %%
def kakao(name,phone,url,realphone):
    # 친구 추가버튼 좌표 : Point(x=1885, y=64)
    # 친구이름 좌표 : Point(x=1313, y=421)
    # 친구 붙여넣기 : Point(x=1565, y=515)
    # 전화번호 좌표 : Point(x=1371, y=471)
    # 전화 붙여넣기 : Point(x=1540, y=584)
    # 친구추가 좌표 : Point(x=1558, y=740)


    # pyautogui.moveTo(1885, 1885, duration=0.5)   # 200, 200 위치로 0.5초간 이동

    pyperclip.copy(phone)         # pyperclip.copy(): 클립보드에 텍스트를 복사합니다.

    pyautogui.click(1885, 64)
    time.sleep(3 * random.random())

    pyautogui.rightClick(1313, 421)
    # pyautogui.press(name)

    # 붙여넣기
    time.sleep(1)
    pyautogui.click(1565, 515)



    time.sleep(1)
    pyperclip.copy(phone)         # pyperclip.copy(): 클립보드에 텍스트를 복사합니다.

    # 전화번호 클릭, 붙여넣기
    pyautogui.rightClick(1371, 471)
    time.sleep(1)
    pyautogui.click(1540, 584)


    # 친구 추가 버튼
    time.sleep(1)
    pyautogui.click(1558,740)

    # 만약 친구가 없었다면 닫기버튼 ; Point(x=1613, y=240)

    time.sleep(1)
    pyautogui.click(1613,240)
    
    # 통합 검색버튼 좌표 : Point(x=1831, y=55)
    # 검색 창 좌표 : Point(x=1164, y=126)
    # 검색 창 붙여넣기 좌표 : Point(x=1452, y=243)
    # 맨 위의 친구이름 좌표 : Point(x=1185, y=222)

    # 채팅창 위치 좌표 : Point(x=1243, y=752)
    # 채팅창 붙여넣기 좌표 : Point(x=1281, y=872)
    # 채팅창 전송버튼 좌표 : Point(x=1700, y=751)
    # 채팅창 닫기 버튼 좌표 : Point(x=1713, y=211)
    # 친구창으로 이동 좌표 : Point(x=1872, y=129)


    pyperclip.copy(phone)         # pyperclip.copy(): 클립보드에 텍스트를 복사합니다.

    pyautogui.click(1831, 55)
    time.sleep(1)

    pyautogui.rightClick(1164, 126)
    time.sleep(1)

    pyautogui.click(1452, 243)

    time.sleep(1)

    pyautogui.doubleClick(1185, 222)

    time.sleep(1)
    
    
    
    # in 채팅방
#     pyperclip.copy(f'안녕하세요 {li[2]} 님 {li[1]} 구매해주셔서 감사합니다. \n {url}' )
    pyperclip.copy(f'안녕하세요. {name}님, {url}, {realphone}')
    pyautogui.rightClick(1062,744)
    time.sleep(1)
    pyautogui.click(1152, 869)
    time.sleep(1)
    pyautogui.click(1272, 744)
    
     # 채팅방 닫기
    time.sleep(1)
    pyautogui.click(1299,117)
    
    # 친구창으로 이동
    time.sleep(1)
    pyautogui.click(1872,129)

# %%
# 본격 진행

for i in range(1000): # 바뀔 예정

    driver.refresh()
    time.sleep(5)

    elems2 = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div/section/div[3]/div[3]/table/tbody')

    n = 0
    li2 = []
    l2 = []

    for i in elems2.find_elements(By.CLASS_NAME,'text--left'):
            
        if n % 10 == 0:
#             print("날짜 : ",i.text)
            l2.append(i.text)
        elif n % 10 == 2:
            l2.append(i.text) # 결제완료 여부
        elif n % 10 == 3:
#             print("컨텐츠 : ",i.text)
            l2.append(i.text)
        elif n % 10 == 5:
#             print("이름 : ",i.text)
            l2.append(i.text)
        elif n % 10 == 7:
#             print("번호 : ",i.text)
            l2.append(i.text)
            li2.append(l2.copy())
            
#             if l2 not in li:

    
            if l2 not in li and l2[1] == '결제완료':
                # 이 고객은 새로운 사람
                # 이 사람꺼 보내준다
                
                # 메뉴 확인해서 링크 변수에 넣기
                url = find_menu(l2[2])
                kakao(l2[3],"01025895645",url,l2[4])
                
                # 카톡 친추하기
                
                # 카톡 보내기 + url로

            l2 = []    
            
        n += 1

    li = copy.deepcopy(li2)
    li2 = []
    
    # 나중에 바꿀 것
    time.sleep(180)

# 마지막에 li2 는 li로

# %%
print(pyautogui.position())
# Out:
# Point(x=1272, y=744)

# %%
l2
# Out:
# ['2022-07-04  14:06:36',
#  '결제완료',
#  '✉️이야기를 전해드릴게요 (2인용) / 50% 할인 특가🔥',
#  '박슬기',
#  '010-2215-0532']
